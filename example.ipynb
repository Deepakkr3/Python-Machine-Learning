# %%
from packege.math import add, sub
from packege.mathsubpackege.mult import mult,div

print(add(10,20))
print(sub(10,20))
print(mult(12,4))
print(div(12,4))
# Out:
# 30
# -10
# 48
# 3.0

# %%
from math import *
print(sqrt(12))
# Out:
# 3.4641016151377544
