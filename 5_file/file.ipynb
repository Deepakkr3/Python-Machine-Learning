# %%
with open("example.txt",'w+') as x:
    x.write("hello this is file")
    x.seek(0)
    print(x.read())
# Out:
# hello this is file

# %%
import os
os.listdir("..")
# Out:
# ['.git',
#  '1_Python_Basics',
#  '2_function',
#  '3_module',
#  '4_library',
#  '5_file',
#  'example.ipynb',
#  'note.txt',
#  'packege',
#  'README.md',
#  'requirement.txt',
#  'z.py']

# %%
# joining file dir
dir_name="folder"
file_name="myfile.txt"
# path=os.path.join(dir_name,file_name)
path=os.path.join(os.getcwd(),file_name)
print(path)
# Out:
# c:\dev\python_ml\5_file\myfile.txt
