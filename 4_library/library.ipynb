# %%
import random
random_int=random.randint(1,10)
random_choice=random.choice(["A","B","C"])
print(random_int)
print(random_choice)
# Out:
# 10
# C

# %%
import os
print(os.getcwd())
# os.makedirs('test_dir')
os.rmdir("test_dir")
# Out:
# c:\dev\python_ml\4_library

# %%
import json
dict_data={"name":"abc","age":23,"class":"A"}
print(type(dict_data))
dict_to_json=json.dumps(dict_data)
print(type(dict_to_json))
print(dict_to_json)
json_to_dict=json.loads(dict_to_json)
print(type(json_to_dict))
# Out:
# <class 'dict'>
# <class 'str'>
# {"name": "abc", "age": 23, "class": "A"}
# <class 'dict'>

# %%
# csv

import csv
# with open('filename',mode='')

# %%
import time

print(time.time())
time.sleep(2)     #sleep 2 sec
print(time.time())
# Out:
# 1764490095.0382588
# 1764490097.0392706

# %%
# Regular Expression

import re
pattern =r"\d+"
text = "There are 34 Apples"
match_res=re.search(pattern,text)

print(match_res)
# Out:
# <re.Match object; span=(10, 12), match='34'>
