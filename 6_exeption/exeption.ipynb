# %%
try: 
    inp=int(input("enter number"))
    val=9/inp
    print("hello this is try block")


 
except (NameError,TypeError,ZeroDivisionError) as x:
    print("exept block",x)
except Exception as ex:
    print(ex)
else:
    print("if try exicute properly")
finally:
    print("it will exicute alwas")
# Out:
# exept block division by zero
# it will exicute alwas
