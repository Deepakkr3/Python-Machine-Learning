# %%
print("hello")
# Out:
# hello

# %%
print("hellon122===========bnnbbn")
# """ welcome """
# Out:
# hellon122===========bnnbbn

# %%
age=20
if age>20:
    print("age is grater than 20",age)
else:
    print("age is less than 20")
    
num=1+1+\
   2
print(num)
# Out:
# age is less than 20
# 4

# %%
x=2;y=10;z=11
print(x,y,z)
# Out:
# 2 10 11

# %%
age =32 # interprator will detact data type at runtime 
print(type(age))
# Out:
# <class 'int'>

# %%
#type mferance
variable1=10
print(variable1)
variable1="deepak"
print(variable1)
# Out:
# 10
# deepak

# %%
#Name error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 #Name error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
if True:
    print("correct outer block 1")
    if False:
        print("incorrect inner block")
    print("correct 2")
print("outside the block")
# Out:
# correct outer block 1
# correct 2
# outside the block

# %%
#variable
#declarition will be at rentime once we give vale besd on
age =23
height=5.10
bolleanVar=True
##printing the variable

print("age ",age)
print("height",height)
print("bool",bolleanVar)
# Out:
# age  23
# height 5.1
# bool True

# %%
height=22.3
print(type(height))
heieight2=str(height)
print(type(heieight2))
# Out:
# <class 'float'>
# <class 'str'>

# %%
age="25"
print(type(int(age)))
# Out:
# <class 'int'>

# %%
age="sdf"
print(int(age))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 age="sdf"
# ----> 2 print(int(age))
#
# ValueError: invalid literal for int() with base 10: 'sdf'

# %%
x=22.1
print(int(x))
y=12
print(float(y))
# Out:
# 22
# 12.0

# %%
age=int(input("enter your age"))
print(type(age),age)
# Out:
# <class 'int'> 43

# %%
num1=int(input("enter first number"))
num2=int(input("eter 2nd number "))

print(num1,num2,num1+num2)
# Out:
# 23 45 68

# %%
#data type
#1 integer
intVar=12
print(type(intVar))

name="deepak"
print(type(name))

is_bool=bool()
print(type(is_bool))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %%
#commmon error
result="hello"+str(3)
upperResult=result.upper()
print(result)
print(upperResult)
# Out:
# hello3
# HELLO3

# %%
#Operators
x=3
y=2
res=x**y
print(res)
flore_dev=x//y
print(flore_dev)
# Out:
# 9
# 1

# %%
#Logical operators


x=True
y=False
print(x and y)
print(x or y)
print(not x)
# Out:
# False
# True
# False

# %%
import streamlit as st
import pandas as pd

st.title("My Streamlit App")

df = pd.DataFrame({
    'A': [1,2,3],
    'B': [4,5,6]
})

st.write(df)
# Out:
# 2025-11-24 23:40:38.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 23:40:38.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 23:40:38.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 23:40:38.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 23:40:38.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 23:40:38.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
