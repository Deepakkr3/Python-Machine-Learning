# %%
# unorder unique

empty_set={}
my_set={1,2,3,4,5,6,7,7}
my_set.add(10)
my_set.remove(7)
print(my_set)
print(type((my_set)))
# Out:
# {1, 2, 3, 4, 5, 6, 10}
# <class 'set'>

# %%
# membership in set
my_set={1,2,3,4,5,6,7,7}
print(30 in my_set)
# Out:
# False

# %%
# math
my_set1={1,2,3,4,5,6,7}
my_set2={3,4,10,11,12,13,14}

# union_set=my_set1.union(my_set2)
# print(union_set)
x=my_set1.intersection_update(my_set2)
print(x)
print(my_set1)
# Out:
# None
# {3, 4}

# %%
words="i am xyz k i am abc"

word=words.split()
print(word)
unique=set(word)
print(unique)
print(len(unique))
# Out:
# ['i', 'am', 'xyz', 'k', 'i', 'am', 'abc']
# {'abc', 'k', 'i', 'xyz', 'am'}
# 5
